# %%
# !pwd
# Out:
# /Users/shubham/Projects/LLM_and_Agents/src

# %%
# !ls
# Out:
# __init__.py        2_tokenize.py      rag                Untitled.ipynb
# 0_gil_test.py      3_embedding.py     README.md          utils
# 1_summarize_url.py 4_viz_embedding.py study_trends

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd()/"rag"))

# %%
# !ls rag
# Out:
# __init__.py      book_splitter.py DGI-INN.pdf      models
# __pycache__      DGI-INN_TOC.pdf  docling.txt      prompts.py

# %%
with open("rag/docling.txt", "r") as f:
    content = f.read()
    sentences = content.split("\\n")
    # for sentence in sentences:
    #     print(sentence)
    nl_content = '\n'.join(sentences)
    print(nl_content)
# Out:
# "[Document(metadata={'source': './rag/DGI-INN_TOC.pdf'}, page_content='## "
#  'CONTENTS\
# \
# |                                                                 '
#  '| Page   '
#  '|\
# |-----------------------------------------------------------------|--------|\
# | '
#  'Foreword                                                        | i      '
#  '|\
# | Preface                                                         | '
#  'ii     |\
# | Introduction                                                    '
#  '| 1      |\
# | Current Diet and Nutrition '
#  'Scenario                             | 3      |\
# | Dietary '
#  'Goals                                                   | 9      |\
# | '
#  'Dietary Guidelines                                              | 10     '
#  '|\
# | Guideline 1                                                     | '
#  '11     |\
# | Guideline 2                                                     '
#  '| 21     |\
# | Guideline '
# ...
